# %%
import pandas as pd

# %%
P = pd.read_csv('jobs_in_data.csv')

# %%
P
# Out:
#       work_year                 job_title                    job_category  \
# 0          2023      Data DevOps Engineer                Data Engineering
# 1          2023            Data Architect  Data Architecture and Modeling
# 2          2023            Data Architect  Data Architecture and Modeling
# 3          2023            Data Scientist       Data Science and Research
# 4          2023            Data Scientist       Data Science and Research
# ...         ...                       ...                             ...
# 9350       2021           Data Specialist    Data Management and Strategy
# 9351       2020            Data Scientist       Data Science and Research
# 9352       2021  Principal Data Scientist       Data Science and Research
# 9353       2020            Data Scientist       Data Science and Research
# 9354       2020     Business Data Analyst                   Data Analysis
#
#      salary_currency  salary  salary_in_usd employee_residence  \
# ...

# %%
P.head(30)
# Out:
#     work_year                    job_title                    job_category  \
# 0        2023         Data DevOps Engineer                Data Engineering
# 1        2023               Data Architect  Data Architecture and Modeling
# 2        2023               Data Architect  Data Architecture and Modeling
# 3        2023               Data Scientist       Data Science and Research
# 4        2023               Data Scientist       Data Science and Research
# 5        2023               Data Scientist       Data Science and Research
# 6        2023               Data Scientist       Data Science and Research
# 7        2023  Machine Learning Researcher         Machine Learning and AI
# 8        2023  Machine Learning Researcher         Machine Learning and AI
# 9        2023                Data Engineer                Data Engineering
# 10       2023                Data Engineer                Data Engineering
# ...

# %%
type(P)
# Out:
# pandas.core.frame.DataFrame

# %%
P.tail(4)
# Out:
#       work_year                 job_title               job_category  \
# 9351       2020            Data Scientist  Data Science and Research
# 9352       2021  Principal Data Scientist  Data Science and Research
# 9353       2020            Data Scientist  Data Science and Research
# 9354       2020     Business Data Analyst              Data Analysis
#
#      salary_currency  salary  salary_in_usd employee_residence  \
# 9351             USD  412000         412000      United States
# 9352             USD  151000         151000      United States
# 9353             USD  105000         105000      United States
# 9354             USD  100000         100000      United States
#
#      experience_level employment_type work_setting company_location  \
# 9351           Senior       Full-time       Remote    United States
# 9352        Mid-level       Full-time       Remote    United States
# 9353      Entry-level       Full-time       Remote    United States
# ...

# %%
P.columns
# Out:
# Index(['work_year', 'job_title', 'job_category', 'salary_currency', 'salary',
#        'salary_in_usd', 'employee_residence', 'experience_level',
#        'employment_type', 'work_setting', 'company_location', 'company_size'],
#       dtype='object')

# %%
# in this 
# 0 represent the starting index
# 6 represent no of columns you want
# 4 represent the skip the no of columns

P.columns[0:6:3]
# Out:
# Index(['work_year', 'salary_currency'], dtype='object')

# %%
P.shape
# Out:
# (9355, 12)

# %%
P
# Out:
#       work_year                 job_title                    job_category  \
# 0          2023      Data DevOps Engineer                Data Engineering
# 1          2023            Data Architect  Data Architecture and Modeling
# 2          2023            Data Architect  Data Architecture and Modeling
# 3          2023            Data Scientist       Data Science and Research
# 4          2023            Data Scientist       Data Science and Research
# ...         ...                       ...                             ...
# 9350       2021           Data Specialist    Data Management and Strategy
# 9351       2020            Data Scientist       Data Science and Research
# 9352       2021  Principal Data Scientist       Data Science and Research
# 9353       2020            Data Scientist       Data Science and Research
# 9354       2020     Business Data Analyst                   Data Analysis
#
#      salary_currency  salary  salary_in_usd employee_residence  \
# ...

# %%
p = P

# %%
p
# Out:
#       work_year                 job_title                    job_category  \
# 0          2023      Data DevOps Engineer                Data Engineering
# 1          2023            Data Architect  Data Architecture and Modeling
# 2          2023            Data Architect  Data Architecture and Modeling
# 3          2023            Data Scientist       Data Science and Research
# 4          2023            Data Scientist       Data Science and Research
# ...         ...                       ...                             ...
# 9350       2021           Data Specialist    Data Management and Strategy
# 9351       2020            Data Scientist       Data Science and Research
# 9352       2021  Principal Data Scientist       Data Science and Research
# 9353       2020            Data Scientist       Data Science and Research
# 9354       2020     Business Data Analyst                   Data Analysis
#
#      salary_currency  salary  salary_in_usd employee_residence  \
# ...

# %%
p.head(30)
# Out:
#     work_year                    job_title                    job_category  \
# 0        2023         Data DevOps Engineer                Data Engineering
# 1        2023               Data Architect  Data Architecture and Modeling
# 2        2023               Data Architect  Data Architecture and Modeling
# 3        2023               Data Scientist       Data Science and Research
# 4        2023               Data Scientist       Data Science and Research
# 5        2023               Data Scientist       Data Science and Research
# 6        2023               Data Scientist       Data Science and Research
# 7        2023  Machine Learning Researcher         Machine Learning and AI
# 8        2023  Machine Learning Researcher         Machine Learning and AI
# 9        2023                Data Engineer                Data Engineering
# 10       2023                Data Engineer                Data Engineering
# ...

# %%
p.tail()
# Out:
#       work_year                 job_title                  job_category  \
# 9350       2021           Data Specialist  Data Management and Strategy
# 9351       2020            Data Scientist     Data Science and Research
# 9352       2021  Principal Data Scientist     Data Science and Research
# 9353       2020            Data Scientist     Data Science and Research
# 9354       2020     Business Data Analyst                 Data Analysis
#
#      salary_currency  salary  salary_in_usd employee_residence  \
# 9350             USD  165000         165000      United States
# 9351             USD  412000         412000      United States
# 9352             USD  151000         151000      United States
# 9353             USD  105000         105000      United States
# 9354             USD  100000         100000      United States
#
#      experience_level employment_type work_setting company_location  \
# 9350           Senior       Full-time       Remote    United States
# ...

# %%
p.shape
# Out:
# (9355, 12)

# %%
p[['salary','employee_residence','experience_level']].head(20)
# Out:
#     salary employee_residence experience_level
# 0    88000            Germany        Mid-level
# 1   186000      United States           Senior
# 2    81800      United States           Senior
# 3   212000      United States           Senior
# 4    93300      United States           Senior
# 5   130000      United States           Senior
# 6   100000      United States           Senior
# 7   224400      United States        Mid-level
# 8   138700      United States        Mid-level
# 9   210000      United States        Executive
# 10  168000      United States        Executive
# 11  224400      United States           Senior
# 12  138700      United States           Senior
# 13   35000     United Kingdom        Mid-level
# 14   30000     United Kingdom        Mid-level
# 15   95000      United States      Entry-level
# 16   75000      United States      Entry-level
# 17  300000      United States           Senior
# 18  234000      United States           Senior
# ...

# %%
p.head(5)
# Out:
#    work_year             job_title                    job_category  \
# 0       2023  Data DevOps Engineer                Data Engineering
# 1       2023        Data Architect  Data Architecture and Modeling
# 2       2023        Data Architect  Data Architecture and Modeling
# 3       2023        Data Scientist       Data Science and Research
# 4       2023        Data Scientist       Data Science and Research
#
#   salary_currency  salary  salary_in_usd employee_residence experience_level  \
# 0             EUR   88000          95012            Germany        Mid-level
# 1             USD  186000         186000      United States           Senior
# 2             USD   81800          81800      United States           Senior
# 3             USD  212000         212000      United States           Senior
# 4             USD   93300          93300      United States           Senior
#
#   employment_type work_setting company_location company_size
# ...

# %%
p['salary'].head(5)
# Out:
# 0     88000
# 1    186000
# 2     81800
# 3    212000
# 4     93300
# Name: salary, dtype: int64

# %%
p.salary.head(5)
# Out:
# 0     88000
# 1    186000
# 2     81800
# 3    212000
# 4     93300
# Name: salary, dtype: int64

# %%
p[p.salary<50000]
# Out:
#       work_year                  job_title                 job_category  \
# 13         2023             Data Scientist    Data Science and Research
# 14         2023             Data Scientist    Data Science and Research
# 68         2023              Data Engineer             Data Engineering
# 123        2023       Data Quality Analyst  Data Quality and Operations
# 124        2023       Data Quality Analyst  Data Quality and Operations
# ...         ...                        ...                          ...
# 9331       2020             Data Scientist    Data Science and Research
# 9332       2021             Data Scientist    Data Science and Research
# 9340       2021              Data Engineer             Data Engineering
# 9345       2020  Machine Learning Engineer      Machine Learning and AI
# 9349       2021              Data Engineer             Data Engineering
#
#      salary_currency  salary  salary_in_usd employee_residence  \
# ...

# %%
# to represent the company location which has spain show

p[p.company_location=='Spain']
# Out:
#       work_year                job_title               job_category  \
# 166        2023           Data Scientist  Data Science and Research
# 167        2023           Data Scientist  Data Science and Research
# 199        2023           Data Scientist  Data Science and Research
# 200        2023           Data Scientist  Data Science and Research
# 608        2023           Data Scientist  Data Science and Research
# ...         ...                      ...                        ...
# 9248       2021             AI Scientist    Machine Learning and AI
# 9275       2021  Data Science Consultant  Data Science and Research
# 9285       2021           Data Scientist  Data Science and Research
# 9331       2020           Data Scientist  Data Science and Research
# 9332       2021           Data Scientist  Data Science and Research
#
#      salary_currency  salary  salary_in_usd employee_residence  \
# 166              EUR   40000          43187              Spain
# ...

# %%
s = p[(p.company_location=='Spain') & (p.employee_residence =='Spain')].head(30)

# %%
s
# Out:
#       work_year                  job_title               job_category  \
# 166        2023             Data Scientist  Data Science and Research
# 167        2023             Data Scientist  Data Science and Research
# 199        2023             Data Scientist  Data Science and Research
# 200        2023             Data Scientist  Data Science and Research
# 608        2023             Data Scientist  Data Science and Research
# 1378       2023             Data Scientist  Data Science and Research
# 1379       2023             Data Scientist  Data Science and Research
# 2006       2023             Data Scientist  Data Science and Research
# 2007       2023             Data Scientist  Data Science and Research
# 2661       2023             Data Scientist  Data Science and Research
# 2662       2023             Data Scientist  Data Science and Research
# 2735       2023                AI Engineer    Machine Learning and AI
# ...

# %%
s[['employee_residence','company_location']]
# Out:
#      employee_residence company_location
# 166               Spain            Spain
# 167               Spain            Spain
# 199               Spain            Spain
# 200               Spain            Spain
# 608               Spain            Spain
# 1378              Spain            Spain
# 1379              Spain            Spain
# 2006              Spain            Spain
# 2007              Spain            Spain
# 2661              Spain            Spain
# 2662              Spain            Spain
# 2735              Spain            Spain
# 2814              Spain            Spain
# 2832              Spain            Spain
# 2953              Spain            Spain
# 2954              Spain            Spain
# 3201              Spain            Spain
# 3202              Spain            Spain
# 3489              Spain            Spain
# 3596              Spain            Spain
# 3597              Spain            Spain
# 3803              Spain            Spain
# ...

# %%
s[['employee_residence','company_location']][p.company_size=='L']
# Out:
# C:\Users\PRANAV\AppData\Local\Temp/ipykernel_13364/494317357.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   s[['employee_residence','company_location']][p.company_size=='L']
#      employee_residence company_location
# 608               Spain            Spain
# 2735              Spain            Spain
# 2814              Spain            Spain
# 4939              Spain            Spain

# %%
p.head(30)
# Out:
#     work_year                    job_title                    job_category  \
# 0        2023         Data DevOps Engineer                Data Engineering
# 1        2023               Data Architect  Data Architecture and Modeling
# 2        2023               Data Architect  Data Architecture and Modeling
# 3        2023               Data Scientist       Data Science and Research
# 4        2023               Data Scientist       Data Science and Research
# 5        2023               Data Scientist       Data Science and Research
# 6        2023               Data Scientist       Data Science and Research
# 7        2023  Machine Learning Researcher         Machine Learning and AI
# 8        2023  Machine Learning Researcher         Machine Learning and AI
# 9        2023                Data Engineer                Data Engineering
# 10       2023                Data Engineer                Data Engineering
# ...

# %%
p[['employee_residence','company_location','company_size']][p.company_size=='L']
# Out:
#      employee_residence company_location company_size
# 0               Germany          Germany            L
# 27        United States    United States            L
# 28        United States    United States            L
# 35        United States    United States            L
# 36        United States    United States            L
# ...                 ...              ...          ...
# 9349              Malta            Malta            L
# 9350      United States    United States            L
# 9351      United States    United States            L
# 9352      United States    United States            L
# 9354      United States    United States            L
#
# [748 rows x 3 columns]

# %%
type(p)
# Out:
# pandas.core.frame.DataFrame

# %%
p.salary.max()
# Out:
# 450000

# %%
p.describe()
# Out:
#          work_year         salary  salary_in_usd
# count  9355.000000    9355.000000    9355.000000
# mean   2022.760449  149927.981293  150299.495564
# std       0.519470   63608.835387   63177.372024
# min    2020.000000   14000.000000   15000.000000
# 25%    2023.000000  105200.000000  105700.000000
# 50%    2023.000000  143860.000000  143000.000000
# 75%    2023.000000  187000.000000  186723.000000
# max    2023.000000  450000.000000  450000.000000

# %%
p[p.salary==p.salary.max()]
# Out:
#       work_year           job_title               job_category  \
# 9157       2020  Research Scientist  Data Science and Research
#
#      salary_currency  salary  salary_in_usd employee_residence  \
# 9157             USD  450000         450000      United States
#
#      experience_level employment_type work_setting company_location  \
# 9157        Mid-level       Full-time    In-person    United States
#
#      company_size
# 9157            M

# %%
p.set_index('work_year')
# Out:
#                           job_title                    job_category  \
# work_year
# 2023           Data DevOps Engineer                Data Engineering
# 2023                 Data Architect  Data Architecture and Modeling
# 2023                 Data Architect  Data Architecture and Modeling
# 2023                 Data Scientist       Data Science and Research
# 2023                 Data Scientist       Data Science and Research
# ...                             ...                             ...
# 2021                Data Specialist    Data Management and Strategy
# 2020                 Data Scientist       Data Science and Research
# 2021       Principal Data Scientist       Data Science and Research
# 2020                 Data Scientist       Data Science and Research
# 2020          Business Data Analyst                   Data Analysis
#
#           salary_currency  salary  salary_in_usd employee_residence  \
# work_year
# ...

# %%
p = P

# %%
P
# Out:
#       work_year                 job_title                    job_category  \
# 0          2023      Data DevOps Engineer                Data Engineering
# 1          2023            Data Architect  Data Architecture and Modeling
# 2          2023            Data Architect  Data Architecture and Modeling
# 3          2023            Data Scientist       Data Science and Research
# 4          2023            Data Scientist       Data Science and Research
# ...         ...                       ...                             ...
# 9350       2021           Data Specialist    Data Management and Strategy
# 9351       2020            Data Scientist       Data Science and Research
# 9352       2021  Principal Data Scientist       Data Science and Research
# 9353       2020            Data Scientist       Data Science and Research
# 9354       2020     Business Data Analyst                   Data Analysis
#
#      salary_currency  salary  salary_in_usd employee_residence  \
# ...

# %%
p
# Out:
#       work_year                 job_title                    job_category  \
# 0          2023      Data DevOps Engineer                Data Engineering
# 1          2023            Data Architect  Data Architecture and Modeling
# 2          2023            Data Architect  Data Architecture and Modeling
# 3          2023            Data Scientist       Data Science and Research
# 4          2023            Data Scientist       Data Science and Research
# ...         ...                       ...                             ...
# 9350       2021           Data Specialist    Data Management and Strategy
# 9351       2020            Data Scientist       Data Science and Research
# 9352       2021  Principal Data Scientist       Data Science and Research
# 9353       2020            Data Scientist       Data Science and Research
# 9354       2020     Business Data Analyst                   Data Analysis
#
#       salary  salary_in_usd employee_residence experience_level  \
# ...

# %%
P.head(10)
# Out:
#    work_year                    job_title                    job_category  \
# 0       2023         Data DevOps Engineer                Data Engineering
# 1       2023               Data Architect  Data Architecture and Modeling
# 2       2023               Data Architect  Data Architecture and Modeling
# 3       2023               Data Scientist       Data Science and Research
# 4       2023               Data Scientist       Data Science and Research
# 5       2023               Data Scientist       Data Science and Research
# 6       2023               Data Scientist       Data Science and Research
# 7       2023  Machine Learning Researcher         Machine Learning and AI
# 8       2023  Machine Learning Researcher         Machine Learning and AI
# 9       2023                Data Engineer                Data Engineering
#
#   salary_currency  salary  salary_in_usd employee_residence experience_level  \
# ...

# %%
# we can also drop the rows by using the array indexing and use axis=0 

P.drop([7],axis=0).head(20)
# Out:
#     work_year                    job_title                    job_category  \
# 0        2023         Data DevOps Engineer                Data Engineering
# 1        2023               Data Architect  Data Architecture and Modeling
# 2        2023               Data Architect  Data Architecture and Modeling
# 3        2023               Data Scientist       Data Science and Research
# 4        2023               Data Scientist       Data Science and Research
# 5        2023               Data Scientist       Data Science and Research
# 6        2023               Data Scientist       Data Science and Research
# 8        2023  Machine Learning Researcher         Machine Learning and AI
# 9        2023                Data Engineer                Data Engineering
# 10       2023                Data Engineer                Data Engineering
# 11       2023    Machine Learning Engineer         Machine Learning and AI
# ...

# %%
P[['salary']].head(20)
# Out:
#     salary
# 0    88000
# 1   186000
# 2    81800
# 3   212000
# 4    93300
# 5   130000
# 6   100000
# 7   224400
# 8   138700
# 9   210000
# 10  168000
# 11  224400
# 12  138700
# 13   35000
# 14   30000
# 15   95000
# 16   75000
# 17  300000
# 18  234000
# 19  140000

# %%
def explore_dataframe(P):
    print("DataFrame methods & attributes:")

# %%
explore_dataframe(P)
# Out:
# DataFrame methods & attributes:

# %%
P.describe()
# Out:
#          work_year         salary  salary_in_usd
# count  9355.000000    9355.000000    9355.000000
# mean   2022.760449  149927.981293  150299.495564
# std       0.519470   63608.835387   63177.372024
# min    2020.000000   14000.000000   15000.000000
# 25%    2023.000000  105200.000000  105700.000000
# 50%    2023.000000  143860.000000  143000.000000
# 75%    2023.000000  187000.000000  186723.000000
# max    2023.000000  450000.000000  450000.000000

# %%
# TO check the methods and attributes which we can use in specific dataset

dir(P)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
# ...

# %%
P.fillna(0)
# Out:
#       work_year                 job_title                    job_category  \
# 0          2023      Data DevOps Engineer                Data Engineering
# 1          2023            Data Architect  Data Architecture and Modeling
# 2          2023            Data Architect  Data Architecture and Modeling
# 3          2023            Data Scientist       Data Science and Research
# 4          2023            Data Scientist       Data Science and Research
# ...         ...                       ...                             ...
# 9350       2021           Data Specialist    Data Management and Strategy
# 9351       2020            Data Scientist       Data Science and Research
# 9352       2021  Principal Data Scientist       Data Science and Research
# 9353       2020            Data Scientist       Data Science and Research
# 9354       2020     Business Data Analyst                   Data Analysis
#
#      salary_currency  salary  salary_in_usd employee_residence  \
# ...

# %%
# here
# 0 represent the starting index
# 10 represent the how much rows you want to fetch
# 2 represent the how much row you want to skip 

P.loc[0:10:2]
# Out:
#     work_year                    job_title                    job_category  \
# 0        2023         Data DevOps Engineer                Data Engineering
# 2        2023               Data Architect  Data Architecture and Modeling
# 4        2023               Data Scientist       Data Science and Research
# 6        2023               Data Scientist       Data Science and Research
# 8        2023  Machine Learning Researcher         Machine Learning and AI
# 10       2023                Data Engineer                Data Engineering
#
#    salary_currency  salary  salary_in_usd employee_residence experience_level  \
# 0              EUR   88000          95012            Germany        Mid-level
# 2              USD   81800          81800      United States           Senior
# 4              USD   93300          93300      United States           Senior
# 6              USD  100000         100000      United States           Senior
# ...

# %%
P.loc[[2,5,7],'salary':'employee_residence']
# Out:
#    salary  salary_in_usd employee_residence
# 2   81800          81800      United States
# 5  130000         130000      United States
# 7  224400         224400      United States

# %%
P.loc[P.salary<40000,'salary':'employee_residence'].head(20)
# Out:
#       salary  salary_in_usd employee_residence
# 13     35000          43064     United Kingdom
# 14     30000          36912     United Kingdom
# 124    30000          36912     United Kingdom
# 165    32000          39372     United Kingdom
# 167    29000          31310              Spain
# 200    36000          38868              Spain
# 209    30000          36912     United Kingdom
# 230    26800          32974     United Kingdom
# 231    26800          32974     United Kingdom
# 610    21000          21000           Pakistan
# 621    35000          43064     United Kingdom
# 622    35000          43064     United Kingdom
# 663    25000          25000            Ukraine
# 914    34800          37573        Netherlands
# 915    30000          36940     United Kingdom
# 956    20000          21593           Portugal
# 1295   36000          36000             Uganda
# 1325   36000          38868           Slovenia
# 1361   36000          38868            Romania
# ...

# %%
P.loc[P.salary==P.salary.max(),'salary']
# Out:
# 9157    450000
# Name: salary, dtype: int64

# %%
P = p

# %%
p
# Out:
#       work_year                 job_title                    job_category  \
# 0          2023      Data DevOps Engineer                Data Engineering
# 1          2023            Data Architect  Data Architecture and Modeling
# 2          2023            Data Architect  Data Architecture and Modeling
# 3          2023            Data Scientist       Data Science and Research
# 4          2023            Data Scientist       Data Science and Research
# ...         ...                       ...                             ...
# 9350       2021           Data Specialist    Data Management and Strategy
# 9351       2020            Data Scientist       Data Science and Research
# 9352       2021  Principal Data Scientist       Data Science and Research
# 9353       2020            Data Scientist       Data Science and Research
# 9354       2020     Business Data Analyst                   Data Analysis
#
#       salary  salary_in_usd employee_residence experience_level  \
# ...

# %%
# check the highest salary with job title

p[['job_title','salary']][p.salary==p.salary.max()]
# Out:
#                job_title  salary
# 9157  Research Scientist  450000

# %%
# find the highest salary for each job title

t = p.groupby('job_title')
t[['job_title','salary']].max()
# Out:
#                                                        job_title  salary
# job_title
# AI Architect                                        AI Architect  330000
# AI Developer                                        AI Developer  275000
# AI Engineer                                          AI Engineer  372000
# AI Programmer                                      AI Programmer  120000
# AI Research Engineer                        AI Research Engineer  150000
# ...                                                          ...     ...
# Sales Data Analyst                            Sales Data Analyst   60000
# Software Data Engineer                    Software Data Engineer  210000
# Staff Data Analyst                            Staff Data Analyst  179998
# Staff Data Scientist                        Staff Data Scientist  164000
# Staff Machine Learning Engineer  Staff Machine Learning Engineer  185000
#
# [125 rows x 2 columns]

# %%
# find the average of salary for each job title


t = p.groupby('job_title')
t[['job_title','salary']].mean()
# Out:
#                                         salary
# job_title
# AI Architect                     249000.000000
# AI Developer                     140500.000000
# AI Engineer                      169208.416667
# AI Programmer                     74000.000000
# AI Research Engineer              67275.000000
# ...                                        ...
# Sales Data Analyst                60000.000000
# Software Data Engineer           120000.000000
# Staff Data Analyst                84999.333333
# Staff Data Scientist             134500.000000
# Staff Machine Learning Engineer  185000.000000
#
# [125 rows x 1 columns]

# %%
# display all the ai engineer job title detail

t.get_group('AI Engineer')
# Out:
#       work_year    job_title             job_category  salary  salary_in_usd  \
# 152        2023  AI Engineer  Machine Learning and AI  220000         220000
# 153        2023  AI Engineer  Machine Learning and AI  176000         176000
# 360        2023  AI Engineer  Machine Learning and AI  212000         212000
# 361        2023  AI Engineer  Machine Learning and AI   93300          93300
# 607        2023  AI Engineer  Machine Learning and AI   50000          50000
# 754        2023  AI Engineer  Machine Learning and AI  190000         190000
# 755        2023  AI Engineer  Machine Learning and AI  160000         160000
# 956        2023  AI Engineer  Machine Learning and AI   20000          21593
# 1031       2023  AI Engineer  Machine Learning and AI  372000         372000
# 1032       2023  AI Engineer  Machine Learning and AI  223000         223000
# 1361       2023  AI Engineer  Machine Learning and AI   36000          38868
# ...

# %%
# alternative of above cell by using location method

p.loc[p.job_title=='AI Engineer']
# Out:
#       work_year    job_title             job_category  salary  salary_in_usd  \
# 152        2023  AI Engineer  Machine Learning and AI  220000         220000
# 153        2023  AI Engineer  Machine Learning and AI  176000         176000
# 360        2023  AI Engineer  Machine Learning and AI  212000         212000
# 361        2023  AI Engineer  Machine Learning and AI   93300          93300
# 607        2023  AI Engineer  Machine Learning and AI   50000          50000
# 754        2023  AI Engineer  Machine Learning and AI  190000         190000
# 755        2023  AI Engineer  Machine Learning and AI  160000         160000
# 956        2023  AI Engineer  Machine Learning and AI   20000          21593
# 1031       2023  AI Engineer  Machine Learning and AI  372000         372000
# 1032       2023  AI Engineer  Machine Learning and AI  223000         223000
# 1361       2023  AI Engineer  Machine Learning and AI   36000          38868
# ...

# %%
# count total number of the title by job title

t.job_title.count().head(20)
# Out:
# job_title
# AI Architect                           12
# AI Developer                           18
# AI Engineer                            36
# AI Programmer                           5
# AI Research Engineer                    4
# AI Scientist                           18
# AWS Data Architect                      1
# Analytics Engineer                    256
# Analytics Engineering Manager           1
# Applied Data Scientist                 11
# Applied Machine Learning Engineer       3
# Applied Machine Learning Scientist     12
# Applied Scientist                     272
# Autonomous Vehicle Technician           2
# Azure Data Engineer                     2
# BI Analyst                             29
# BI Data Analyst                        16
# BI Data Engineer                        1
# BI Developer                           52
# Big Data Architect                      2
# Name: job_title, dtype: int64

# %%
# alternative of above cell by using the value count 

p['job_title'].value_counts().head(20)
# Out:
# Data Engineer                     2195
# Data Scientist                    1989
# Data Analyst                      1388
# Machine Learning Engineer          991
# Applied Scientist                  272
# Research Scientist                 269
# Analytics Engineer                 256
# Data Architect                     213
# Business Intelligence Engineer     144
# Research Engineer                  144
# Data Manager                       132
# ML Engineer                        106
# Data Science Manager                88
# Machine Learning Scientist          76
# Business Intelligence Analyst       54
# BI Developer                        52
# Data Science Consultant             44
# Data Specialist                     40
# Research Analyst                    39
# Decision Scientist                  38
# Name: job_title, dtype: int64
